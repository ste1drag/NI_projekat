# %%
import pandas as pd
import numpy as np
from add_rankings import add_rankings
from sklearn import linear_model

# %%
def calculate_team_stats(path):
    df = pd.read_excel(path)

    required_columns = ['Club', '2FG', '3FG', 'FT', 'Fouls(Rv)', 'PIR']
    if not all(column in df.columns for column in required_columns):
        raise ValueError(f"The file must contain required columns")
    
    df[['2pt_made','2pt_attempted']] = df['2FG'].str.split('/', expand = True).astype(int)
    df[['3pt_made','3pt_attempted']] = df['3FG'].str.split('/', expand = True).astype(int)
    df[['ft_made','ft_attempted']] = df['FT'].str.split('/', expand = True).astype(int)

    df['Fouls(Rv)'] = df['Fouls(Rv)'].astype(int)
    df['PIR'] = df['PIR'].astype(int)

    team_stats = df.groupby('Club').agg({
        '2pt_made': 'sum',
        '3pt_made': 'sum',
        'ft_made': 'sum',
        'Fouls(Rv)':'sum',
        'PIR': 'sum'
    }).reset_index()

    return team_stats

# %%
path = 'data/Euroleague_20_21.xlsx'
team_stats = calculate_team_stats(path)

# %%
team_stats
# Out:
#                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 1                  Alba Berlin       647       342      354        664  2863
# 2                 Anadolu Efes       795       418      609        836  3908
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 4                  CSKA Moscow       759       388      599        847  3516
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
# 6                 FC Barcelona       855       324      598        866  3566
# 7             FC Bayern Munich       831       281      561        801  3201
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 9         Khimki Moscow Region       620       315      449        630  2626
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 14                 Real Madrid       720       400      458        734  3429
# 15             Valencia Basket       668       318      493        697  3075
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 17         Zenit St Petersburg       705       358      537        803  3266

# %%
team_stats['score'] = 47.19 + 0.15 * team_stats['Fouls(Rv)'] + 0.78 * team_stats['2pt_made'] + 1.39 * team_stats['3pt_made'] + 0.54 * team_stats['ft_made']

# %%
team_stats
# Out:
#                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR  \
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 1                  Alba Berlin       647       342      354        664  2863
# 2                 Anadolu Efes       795       418      609        836  3908
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 4                  CSKA Moscow       759       388      599        847  3516
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
# 6                 FC Barcelona       855       324      598        866  3566
# 7             FC Bayern Munich       831       281      561        801  3201
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 9         Khimki Moscow Region       620       315      449        630  2626
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 14                 Real Madrid       720       400      458        734  3429
# 15             Valencia Basket       668       318      493        697  3075
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 17         Zenit St Petersburg       705       358      537        803  3266
#
#       score
# 0   1647.69
# 1   1317.99
# 2   1702.57
# 3   1356.71
# 4   1629.04
# 5   1266.73
# 6   1617.27
# 7   1509.05
# 8   1401.61
# 9   1305.60
# 10  1296.34
# 11  1317.15
# 12  1327.48
# 13  1341.69
# 14  1522.21
# 15  1381.02
# 16  1295.63
# 17  1505.14

# %%
team_stats = team_stats.sort_values(by=['score']).iloc[::-1]

# %%
team_stats
# Out:
#                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR  \
# 2                 Anadolu Efes       795       418      609        836  3908
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 4                  CSKA Moscow       759       388      599        847  3516
# 6                 FC Barcelona       855       324      598        866  3566
# 14                 Real Madrid       720       400      458        734  3429
# 7             FC Bayern Munich       831       281      561        801  3201
# 17         Zenit St Petersburg       705       358      537        803  3266
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 15             Valencia Basket       668       318      493        697  3075
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 1                  Alba Berlin       647       342      354        664  2863
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 9         Khimki Moscow Region       620       315      449        630  2626
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
#
#       score
# 2   1702.57
# 0   1647.69
# 4   1629.04
# 6   1617.27
# 14  1522.21
# 7   1509.05
# 17  1505.14
# 8   1401.61
# 15  1381.02
# 3   1356.71
# 13  1341.69
# 12  1327.48
# 1   1317.99
# 11  1317.15
# 9   1305.60
# 10  1296.34
# 16  1295.63
# 5   1266.73

# %%
team_stats_pir = team_stats.sort_values(by=['PIR']).iloc[::-1]

# %%
team_stats_pir
# Out:
#                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR  \
# 2                 Anadolu Efes       795       418      609        836  3908
# 6                 FC Barcelona       855       324      598        866  3566
# 4                  CSKA Moscow       759       388      599        847  3516
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 14                 Real Madrid       720       400      458        734  3429
# 17         Zenit St Petersburg       705       358      537        803  3266
# 7             FC Bayern Munich       831       281      561        801  3201
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 15             Valencia Basket       668       318      493        697  3075
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 1                  Alba Berlin       647       342      354        664  2863
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 9         Khimki Moscow Region       620       315      449        630  2626
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
#
#       score
# 2   1702.57
# 6   1617.27
# 4   1629.04
# 0   1647.69
# 14  1522.21
# 17  1505.14
# 7   1509.05
# 3   1356.71
# 8   1401.61
# 15  1381.02
# 16  1295.63
# 1   1317.99
# 13  1341.69
# 12  1327.48
# 11  1317.15
# 10  1296.34
# 9   1305.60
# 5   1266.73

# %%
data = add_rankings('data/euroleague_teams.csv')

# %%
training_data = data[data['ranking'].notna()]

# %%
training_data
# Out:
#     season_team_id season_code team_id  games_played  minutes  points  \
# 216      E2016_BAM       E2016     BAM          30.0   1214.3    2397
# 217      E2016_BAR       E2016     BAR          30.0   1205.0    2141
# 218      E2016_BAS       E2016     BAS          33.0   1319.8    2705
# 219      E2016_CSK       E2016     CSK          35.0   1409.9    3063
# 220      E2016_DAR       E2016     DAR          34.0   1365.0    2691
# ..             ...         ...     ...           ...      ...     ...
# 331      E2022_RED       E2022     RED          34.0   1375.0    2626
# 332      E2022_TEL       E2022     TEL          39.0   1565.0    3262
# 333      E2022_ULK       E2022     ULK          39.0   1575.0    3229
# 334      E2022_VIR       E2022     VIR          34.0   1365.0    2653
# 335      E2022_ZAL       E2022     ZAL          37.0   1480.0    2807
#
#      two_points_made  two_points_attempted  three_points_made  \
# 216              602                  1098                280
# 217              496                  1022                271
# 218              719                  1349                270
# 219              745                  1351                305
# 220              646                  1322                304
# ..               ...                   ...                ...
# 331              657                  1205                281
# 332              841                  1521                348
# 333              814                  1469                372
# 334              628                  1151                301
# 335              708                  1371                288
#
#      three_points_attempted  ...  total_rebounds_per_game  assists_per_game  \
# 216                     697  ...                    31.57             18.23
# 217                     716  ...                    33.83             17.23
# 218                     763  ...                    36.55             18.39
# 219                     756  ...                    33.46             19.86
# 220                     826  ...                    34.88             13.97
# ..                      ...  ...                      ...               ...
# 331                     832  ...                    32.76             16.91
# 332                    1000  ...                    35.69             16.38
# 333                     997  ...                    33.49             17.97
# 334                     805  ...                    30.79             19.44
# 335                     797  ...                    33.32             13.70
#
#      steals_per_game  turnovers_per_game  blocks_favour_per_game  \
# 216             5.47               12.50                    2.73
# 217             7.07               14.77                    2.03
# 218             6.70               13.70                    3.03
# 219             7.11               14.31                    3.23
# 220             6.15               11.09                    2.47
# ..               ...                 ...                     ...
# 331             6.65               12.53                    1.65
# 332             6.62               11.44                    2.90
# 333             6.49               11.77                    1.59
# 334             7.12               14.53                    2.09
# 335             6.00               12.95                    2.46
#
#      blocks_against_per_game  fouls_committed_per_game  \
# 216                     2.57                     21.93
# 217                     2.13                     18.43
# 218                     2.82                     21.58
# 219                     3.09                     22.60
# 220                     3.82                     20.32
# ..                       ...                       ...
# 331                     2.65                     21.47
# 332                     2.13                     22.44
# 333                     2.46                     20.79
# 334                     2.47                     20.88
# 335                     2.81                     20.65
#
#      fouls_received_per_game  valuation_per_game  ranking
# 216                    18.93               86.13     13.0
# 217                    19.83               79.67     11.0
# 218                    20.64               90.85      8.0
# 219                    22.80               99.69      1.0
# 220                    20.76               81.71      9.0
# ..                       ...                 ...      ...
# 331                    20.12               82.35     11.0
# 332                    19.26               90.74      5.0
# 333                    20.41               90.13      7.0
# 334                    20.06               85.65     14.0
# 335                    20.27               80.05      9.0
#
# [119 rows x 46 columns]

# %%
test_data = data[data['season_team_id'].str.startswith('E2023')]

# %%
test_data
# Out:
#     season_team_id season_code team_id  games_played  minutes  points  \
# 336      E2023_ASV       E2023     ASV          34.0   1370.0    2674
# 337      E2023_BAR       E2023     BAR          39.0   1565.0    3163
# 338      E2023_BAS       E2023     BAS          39.0   1565.0    3300
# 339      E2023_BER       E2023     BER          34.0   1360.0    2591
# 340      E2023_IST       E2023     IST          35.0   1425.0    2992
# 341      E2023_MAD       E2023     MAD          39.0   1590.0    3459
# 342      E2023_MCO       E2023     MCO          39.0   1575.0    3189
# 343      E2023_MIL       E2023     MIL          34.0   1370.0    2659
# 344      E2023_MUN       E2023     MUN          34.0   1385.0    2674
# 345      E2023_OLY       E2023     OLY          41.0   1660.0    3229
# 346      E2023_PAM       E2023     PAM          34.0   1365.0    2582
# 347      E2023_PAN       E2023     PAN          41.0   1653.0    3380
# 348      E2023_PAR       E2023     PAR          34.0   1375.0    2822
# 349      E2023_RED       E2023     RED          34.0   1360.0    2764
# 350      E2023_TEL       E2023     TEL          40.0   1603.0    3508
# 351      E2023_ULK       E2023     ULK          41.0   1670.0    3449
# 352      E2023_VIR       E2023     VIR          36.0   1440.0    2872
# 353      E2023_ZAL       E2023     ZAL          34.0   1365.0    2702
#
#      two_points_made  two_points_attempted  three_points_made  \
# 336              744                  1388                244
# 337              856                  1568                328
# 338              752                  1351                424
# 339              641                  1260                302
# 340              747                  1346                348
# 341              820                  1414                407
# 342              849                  1601                305
# 343              615                  1116                341
# 344              649                  1215                336
# 345              772                  1396                387
# 346              686                  1309                247
# 347              812                  1475                377
# 348              750                  1282                273
# 349              680                  1239                314
# 350              919                  1710                356
# 351              759                  1365                470
# 352              702                  1295                338
# 353              646                  1217                331
#
#      three_points_attempted  ...  total_rebounds_per_game  assists_per_game  \
# 336                     723  ...                    33.97             17.82
# 337                     912  ...                    35.85             19.31
# 338                    1143  ...                    34.97             18.97
# 339                     860  ...                    32.44             16.44
# 340                     940  ...                    32.54             17.63
# 341                    1076  ...                    36.44             20.59
# 342                     872  ...                    33.87             16.05
# 343                     930  ...                    32.12             16.29
# 344                     938  ...                    35.41             16.09
# 345                    1030  ...                    33.20             19.02
# 346                     754  ...                    34.32             16.18
# 347                     966  ...                    33.76             16.59
# 348                     755  ...                    30.91             15.09
# 349                     920  ...                    34.74             18.47
# 350                     973  ...                    35.60             19.58
# 351                    1199  ...                    33.29             18.05
# 352                     936  ...                    32.75             18.61
# 353                     851  ...                    31.88             15.65
#
#      steals_per_game  turnovers_per_game  blocks_favour_per_game  \
# 336             6.03               12.97                    1.62
# 337             6.41               12.79                    2.28
# 338             5.51               12.46                    2.21
# 339             7.00               15.09                    2.15
# 340             7.03               10.34                    3.14
# 341             6.51               12.03                    3.62
# 342             6.87                9.97                    1.82
# 343             7.00               12.44                    2.12
# 344             6.06               13.03                    2.62
# 345             7.17               12.15                    2.61
# 346             6.47               13.62                    1.82
# 347             6.76               12.46                    2.68
# 348             6.56               12.44                    2.32
# 349             6.59               12.12                    2.47
# 350             7.10               11.68                    3.05
# 351             5.85               12.07                    2.22
# 352             6.64               12.31                    2.69
# 353             6.50               12.59                    1.74
#
#      blocks_against_per_game  fouls_committed_per_game  \
# 336                     3.29                     18.41
# 337                     1.92                     19.85
# 338                     3.38                     18.18
# 339                     3.50                     18.32
# 340                     2.14                     18.31
# 341                     1.56                     18.90
# 342                     2.21                     19.62
# 343                     1.74                     19.56
# 344                     2.47                     20.65
# 345                     2.41                     18.93
# 346                     3.12                     21.15
# 347                     2.41                     17.68
# 348                     1.59                     21.06
# 349                     2.74                     21.56
# 350                     2.33                     20.38
# 351                     1.73                     21.39
# 352                     2.19                     21.58
# 353                     2.88                     21.18
#
#      fouls_received_per_game  valuation_per_game  ranking
# 336                    19.35               85.82      NaN
# 337                    18.95               91.59      NaN
# 338                    18.79               93.05      NaN
# 339                    18.18               77.76      NaN
# 340                    18.51               96.51      NaN
# 341                    20.08              107.56      NaN
# 342                    21.56               91.36      NaN
# 343                    18.97               85.47      NaN
# 344                    18.79               84.38      NaN
# 345                    19.61               91.24      NaN
# 346                    19.12               78.71      NaN
# 347                    21.63               95.32      NaN
# 348                    20.41               90.12      NaN
# 349                    19.88               88.71      NaN
# 350                    19.40               98.58      NaN
# 351                    19.73               92.20      NaN
# 352                    19.56               86.69      NaN
# 353                    18.32               81.94      NaN
#
# [18 rows x 46 columns]

# %%
model = linear_model.LinearRegression()

# %%
training_data_ranking = training_data['ranking']

# %%
training_data['two_points_percentage'] = training_data['two_points_made_per_game'] / training_data['two_points_attempted_per_game']
training_data['three_points_percentage'] = training_data['three_points_made_per_game'] / training_data['three_points_attempted_per_game']
training_data['free_throws_percentage'] = training_data['free_throws_made_per_game'] / training_data['free_throws_attempted_per_game']
parameters = ['two_points_percentage','three_points_percentage','free_throws_percentage','offensive_rebounds_per_game','defensive_rebounds_per_game','assists_per_game','steals_per_game','turnovers_per_game','fouls_received_per_game']
# Out:
# C:\Users\steva\AppData\Local\Temp\ipykernel_2424\3193224468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['two_points_percentage'] = training_data['two_points_made_per_game'] / training_data['two_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_2424\3193224468.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['three_points_percentage'] = training_data['three_points_made_per_game'] / training_data['three_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_2424\3193224468.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['free_throws_percentage'] = training_data['free_throws_made_per_game'] / training_data['free_throws_attempted_per_game']

# %%
training_data = training_data[parameters]

# %%
training_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 216               0.548361                 0.401636                0.783100
# 217               0.485178                 0.378299                0.736842
# 218               0.533023                 0.353806                0.763085
# 219               0.551554                 0.403241                0.821319
# 220               0.488683                 0.368053                0.733231
# ..                     ...                      ...                     ...
# 331               0.545147                 0.337556                0.775155
# 332               0.552821                 0.347894                0.792845
# 333               0.554022                 0.373239                0.722836
# 334               0.545643                 0.373733                0.793122
# 335               0.516599                 0.361188                0.803158
#
#      offensive_rebounds_per_game  defensive_rebounds_per_game  \
# 216                         7.43                        24.13
# 217                         9.40                        24.43
# 218                        11.18                        25.36
# 219                         9.46                        24.00
# 220                        11.68                        23.21
# ..                           ...                          ...
# 331                        10.41                        22.35
# 332                        11.90                        23.79
# 333                        11.38                        22.10
# 334                         7.97                        22.82
# 335                        11.14                        22.19
#
#      assists_per_game  steals_per_game  turnovers_per_game  \
# 216             18.23             5.47               12.50
# 217             17.23             7.07               14.77
# 218             18.39             6.70               13.70
# 219             19.86             7.11               14.31
# 220             13.97             6.15               11.09
# ..                ...              ...                 ...
# 331             16.91             6.65               12.53
# 332             16.38             6.62               11.44
# 333             17.97             6.49               11.77
# 334             19.44             7.12               14.53
# 335             13.70             6.00               12.95
#
#      fouls_received_per_game
# 216                    18.93
# 217                    19.83
# 218                    20.64
# 219                    22.80
# 220                    20.76
# ..                       ...
# 331                    20.12
# 332                    19.26
# 333                    20.41
# 334                    20.06
# 335                    20.27
#
# [119 rows x 9 columns]

# %%
model.fit(training_data,training_data_ranking)
# Out:
# LinearRegression()

# %%
test_data['two_points_percentage'] = test_data['two_points_made_per_game'] / test_data['two_points_attempted_per_game']
test_data['three_points_percentage'] = test_data['three_points_made_per_game'] / test_data['three_points_attempted_per_game']
test_data['free_throws_percentage'] = test_data['free_throws_made_per_game'] / test_data['free_throws_attempted_per_game']
# Out:
# C:\Users\steva\AppData\Local\Temp\ipykernel_2424\1492303578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['two_points_percentage'] = test_data['two_points_made_per_game'] / test_data['two_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_2424\1492303578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['three_points_percentage'] = test_data['three_points_made_per_game'] / test_data['three_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_2424\1492303578.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['free_throws_percentage'] = test_data['free_throws_made_per_game'] / test_data['free_throws_attempted_per_game']

# %%
test_data = test_data[parameters]

# %%
test_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 336               0.536012                 0.337723                0.773465
# 337               0.545884                 0.359709                0.725894
# 338               0.556582                 0.370863                0.761905
# 339               0.508635                 0.351127                0.791583
# 340               0.554862                 0.370067                0.812148
# 341               0.579978                 0.378398                0.814559
# 342               0.530329                 0.349732                0.748227
# 343               0.551188                 0.366728                0.776333
# 344               0.534135                 0.358101                0.797935
# 345               0.553010                 0.375796                0.729869
# 346               0.524156                 0.327322                0.773850
# 347               0.550306                 0.390492                0.736944
# 348               0.584991                 0.361549                0.818937
# 349               0.548847                 0.341463                0.769972
# 350               0.537544                 0.365954                0.778986
# 351               0.556023                 0.391929                0.793383
# 352               0.542118                 0.361154                0.751490
# 353               0.530875                 0.389133                0.809241
#
#      offensive_rebounds_per_game  defensive_rebounds_per_game  \
# 336                        10.29                        23.68
# 337                        11.54                        24.31
# 338                        10.49                        24.49
# 339                        10.82                        21.62
# 340                        10.29                        22.26
# 341                         9.82                        26.62
# 342                        11.03                        22.85
# 343                         8.88                        23.24
# 344                        10.71                        24.71
# 345                         9.68                        23.51
# 346                        10.15                        24.18
# 347                         9.93                        23.83
# 348                         9.12                        21.79
# 349                        11.85                        22.88
# 350                        13.08                        22.52
# 351                        10.24                        23.05
# 352                         9.56                        23.19
# 353                         9.74                        22.15
#
#      assists_per_game  steals_per_game  turnovers_per_game  \
# 336             17.82             6.03               12.97
# 337             19.31             6.41               12.79
# 338             18.97             5.51               12.46
# 339             16.44             7.00               15.09
# 340             17.63             7.03               10.34
# 341             20.59             6.51               12.03
# 342             16.05             6.87                9.97
# 343             16.29             7.00               12.44
# 344             16.09             6.06               13.03
# 345             19.02             7.17               12.15
# 346             16.18             6.47               13.62
# 347             16.59             6.76               12.46
# 348             15.09             6.56               12.44
# 349             18.47             6.59               12.12
# 350             19.58             7.10               11.68
# 351             18.05             5.85               12.07
# 352             18.61             6.64               12.31
# 353             15.65             6.50               12.59
#
#      fouls_received_per_game
# 336                    19.35
# 337                    18.95
# 338                    18.79
# 339                    18.18
# 340                    18.51
# 341                    20.08
# 342                    21.56
# 343                    18.97
# 344                    18.79
# 345                    19.61
# 346                    19.12
# 347                    21.63
# 348                    20.41
# 349                    19.88
# 350                    19.40
# 351                    19.73
# 352                    19.56
# 353                    18.32

# %%
rankings_2023_predicted = model.predict(test_data)

# %%
test_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 336               0.536012                 0.337723                0.773465
# 337               0.545884                 0.359709                0.725894
# 338               0.556582                 0.370863                0.761905
# 339               0.508635                 0.351127                0.791583
# 340               0.554862                 0.370067                0.812148
# 341               0.579978                 0.378398                0.814559
# 342               0.530329                 0.349732                0.748227
# 343               0.551188                 0.366728                0.776333
# 344               0.534135                 0.358101                0.797935
# 345               0.553010                 0.375796                0.729869
# 346               0.524156                 0.327322                0.773850
# 347               0.550306                 0.390492                0.736944
# 348               0.584991                 0.361549                0.818937
# 349               0.548847                 0.341463                0.769972
# 350               0.537544                 0.365954                0.778986
# 351               0.556023                 0.391929                0.793383
# 352               0.542118                 0.361154                0.751490
# 353               0.530875                 0.389133                0.809241
#
#      offensive_rebounds_per_game  defensive_rebounds_per_game  \
# 336                        10.29                        23.68
# 337                        11.54                        24.31
# 338                        10.49                        24.49
# 339                        10.82                        21.62
# 340                        10.29                        22.26
# 341                         9.82                        26.62
# 342                        11.03                        22.85
# 343                         8.88                        23.24
# 344                        10.71                        24.71
# 345                         9.68                        23.51
# 346                        10.15                        24.18
# 347                         9.93                        23.83
# 348                         9.12                        21.79
# 349                        11.85                        22.88
# 350                        13.08                        22.52
# 351                        10.24                        23.05
# 352                         9.56                        23.19
# 353                         9.74                        22.15
#
#      assists_per_game  steals_per_game  turnovers_per_game  \
# 336             17.82             6.03               12.97
# 337             19.31             6.41               12.79
# 338             18.97             5.51               12.46
# 339             16.44             7.00               15.09
# 340             17.63             7.03               10.34
# 341             20.59             6.51               12.03
# 342             16.05             6.87                9.97
# 343             16.29             7.00               12.44
# 344             16.09             6.06               13.03
# 345             19.02             7.17               12.15
# 346             16.18             6.47               13.62
# 347             16.59             6.76               12.46
# 348             15.09             6.56               12.44
# 349             18.47             6.59               12.12
# 350             19.58             7.10               11.68
# 351             18.05             5.85               12.07
# 352             18.61             6.64               12.31
# 353             15.65             6.50               12.59
#
#      fouls_received_per_game
# 336                    19.35
# 337                    18.95
# 338                    18.79
# 339                    18.18
# 340                    18.51
# 341                    20.08
# 342                    21.56
# 343                    18.97
# 344                    18.79
# 345                    19.61
# 346                    19.12
# 347                    21.63
# 348                    20.41
# 349                    19.88
# 350                    19.40
# 351                    19.73
# 352                    19.56
# 353                    18.32

# %%
model.coef_
# Out:
# array([-71.54454335, -86.19463086,   5.69586831,  -0.92624566,
#         -1.37459459,   0.33891153,  -1.52459452,   1.10456036,
#         -0.87039763])

# %%
sorted_ranking = sorted(rankings_2023_predicted)

order_ranking = {value: index + 1 for index, value in enumerate(sorted_ranking)}

result = [order_ranking[value] for value in rankings_2023_predicted]

# %%
result
# Out:
# [16, 9, 10, 18, 7, 1, 3, 11, 13, 4, 17, 2, 8, 12, 6, 5, 14, 15]

# %%
test_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 336               0.536012                 0.337723                0.773465
# 337               0.545884                 0.359709                0.725894
# 338               0.556582                 0.370863                0.761905
# 339               0.508635                 0.351127                0.791583
# 340               0.554862                 0.370067                0.812148
# 341               0.579978                 0.378398                0.814559
# 342               0.530329                 0.349732                0.748227
# 343               0.551188                 0.366728                0.776333
# 344               0.534135                 0.358101                0.797935
# 345               0.553010                 0.375796                0.729869
# 346               0.524156                 0.327322                0.773850
# 347               0.550306                 0.390492                0.736944
# 348               0.584991                 0.361549                0.818937
# 349               0.548847                 0.341463                0.769972
# 350               0.537544                 0.365954                0.778986
# 351               0.556023                 0.391929                0.793383
# 352               0.542118                 0.361154                0.751490
# 353               0.530875                 0.389133                0.809241
#
#      offensive_rebounds_per_game  defensive_rebounds_per_game  \
# 336                        10.29                        23.68
# 337                        11.54                        24.31
# 338                        10.49                        24.49
# 339                        10.82                        21.62
# 340                        10.29                        22.26
# 341                         9.82                        26.62
# 342                        11.03                        22.85
# 343                         8.88                        23.24
# 344                        10.71                        24.71
# 345                         9.68                        23.51
# 346                        10.15                        24.18
# 347                         9.93                        23.83
# 348                         9.12                        21.79
# 349                        11.85                        22.88
# 350                        13.08                        22.52
# 351                        10.24                        23.05
# 352                         9.56                        23.19
# 353                         9.74                        22.15
#
#      assists_per_game  steals_per_game  turnovers_per_game  \
# 336             17.82             6.03               12.97
# 337             19.31             6.41               12.79
# 338             18.97             5.51               12.46
# 339             16.44             7.00               15.09
# 340             17.63             7.03               10.34
# 341             20.59             6.51               12.03
# 342             16.05             6.87                9.97
# 343             16.29             7.00               12.44
# 344             16.09             6.06               13.03
# 345             19.02             7.17               12.15
# 346             16.18             6.47               13.62
# 347             16.59             6.76               12.46
# 348             15.09             6.56               12.44
# 349             18.47             6.59               12.12
# 350             19.58             7.10               11.68
# 351             18.05             5.85               12.07
# 352             18.61             6.64               12.31
# 353             15.65             6.50               12.59
#
#      fouls_received_per_game
# 336                    19.35
# 337                    18.95
# 338                    18.79
# 339                    18.18
# 340                    18.51
# 341                    20.08
# 342                    21.56
# 343                    18.97
# 344                    18.79
# 345                    19.61
# 346                    19.12
# 347                    21.63
# 348                    20.41
# 349                    19.88
# 350                    19.40
# 351                    19.73
# 352                    19.56
# 353                    18.32

# %%
# implementing genetic algorithm

# %%
num_of_generations = 1000
population = np.random.rand(100, len(parameters))

# %%
len(population)
# Out:
# 100

# %%
crossover = np.random.rand()
# Out:
# 0.2946061318516391

# %%
def fitness_score(chromosome, stats, rankings):
    rankings_prediction = stats.dot(chromosome)
    MSE = np.square(np.subtract(rankings,rankings_prediction)).mean()
    return 1 / (1+MSE)

# %%
fitness_scores = np.array([fitness_score(chrom, training_data, training_data_ranking) for chrom in population])
len(fitness_scores)
# Out:
# 100

# %%
population_with_scores = [{'chromosome': population[i], 'fitness_score': fitness_scores[i]} for i in range(len(fitness_scores))]

# %%
population_with_scores
# Out:
# [{'chromosome': array([0.99921014, 0.44383131, 0.24952115, 0.82269324, 0.78400617,
#          0.92790044, 0.7777993 , 0.27050535, 0.01720108]),
#   'fitness_score': 0.0005261346753089941},
#  {'chromosome': array([0.67117207, 0.00656251, 0.30286042, 0.46942086, 0.9509693 ,
#          0.55150581, 0.35063705, 0.90541254, 0.94169795]),
#   'fitness_score': 0.00027014430064938624},
#  {'chromosome': array([0.64667221, 0.45127938, 0.81924001, 0.62838907, 0.87947592,
#          0.07271726, 0.24685516, 0.44964327, 0.31371544]),
#   'fitness_score': 0.0008560091579933216},
#  {'chromosome': array([0.08835024, 0.11747325, 0.32002659, 0.72560527, 0.98902389,
#          0.71803191, 0.00566154, 0.88070645, 0.61228285]),
#   'fitness_score': 0.0002997712642165637},
#  {'chromosome': array([0.74783189, 0.8589608 , 0.05936465, 0.86784931, 0.84268951,
#          0.98044076, 0.33886244, 0.08169183, 0.46313514]),
#   'fitness_score': 0.00040065976976735125},
#  {'chromosome': array([0.24482144, 0.69596964, 0.2474848 , 0.75480266, 0.23002288,
#          0.91905312, 0.2521977 , 0.1041195 , 0.24224998]),
#   'fitness_score': 0.0012044597063481908},
#  {'chromosome': array([0.70929104, 0.27523884, 0.94718322, 0.84819712, 0.05403928,
#          0.36477175, 0.17970258, 0.54511222, 0.97992745]),
#   'fitness_score': 0.0007485125879841554},
#  {'chromosome': array([0.51236911, 0.72447163, 0.04419263, 0.91253428, 0.2025729 ,
#          0.56749891, 0.3872893 , 0.71516466, 0.99797007]),
#   'fitness_score': 0.0004474708759027614},
#  {'chromosome': array([0.91759831, 0.09995769, 0.02442391, 0.97615067, 0.46851287,
#          0.96302726, 0.91684114, 0.91698667, 0.39231547]),
#   'fitness_score': 0.00033562757397314713},
#  {'chromosome': array([0.93933926, 0.17070382, 0.50338605, 0.87281771, 0.00564485,
#          0.63364878, 0.47448563, 0.2839411 , 0.07048228]),
#   'fitness_score': 0.002349947893918685},
#  {'chromosome': array([0.20689443, 0.83845888, 0.16344008, 0.55141897, 0.06823181,
#          0.58474318, 0.70162045, 0.05115581, 0.10450639]),
#   'fitness_score': 0.00346124508874568},
#  {'chromosome': array([0.00784434, 0.63228875, 0.05884512, 0.275312  , 0.171393  ,
#          0.00715343, 0.37624189, 0.31142714, 0.84226974]),
#   'fitness_score': 0.002033543726321261},
#  {'chromosome': array([0.74580649, 0.89120783, 0.56238816, 0.828239  , 0.42715152,
#          0.24242664, 0.15909839, 0.32641357, 0.78839003]),
#   'fitness_score': 0.0007666731790432396},
#  {'chromosome': array([0.25026295, 0.45379355, 0.37055094, 0.07008978, 0.88723806,
#          0.79319292, 0.32832196, 0.00850686, 0.70114396]),
#   'fitness_score': 0.0005316157453820642},
#  {'chromosome': array([0.58304467, 0.97662463, 0.20317195, 0.8667109 , 0.50737603,
#          0.14575754, 0.7391864 , 0.9162457 , 0.61039386]),
#   'fitness_score': 0.0005205942165725892},
#  {'chromosome': array([0.29152603, 0.77460277, 0.75272282, 0.40916688, 0.96216001,
#          0.35821139, 0.01722834, 0.82112249, 0.82360854]),
#   'fitness_score': 0.0003696175207509391},
#  {'chromosome': array([0.51168645, 0.62999953, 0.72671574, 0.56544828, 0.08241212,
#          0.84815575, 0.85346411, 0.68920065, 0.06880984]),
#   'fitness_score': 0.0010829020652611669},
#  {'chromosome': array([0.16138116, 0.93394761, 0.37016889, 0.44111471, 0.00974472,
#          0.85001823, 0.14045911, 0.78915772, 0.58010096]),
#   'fitness_score': 0.0008634004363514307},
#  {'chromosome': array([0.8265403 , 0.7445839 , 0.53016339, 0.05933899, 0.65865918,
#          0.74512193, 0.5271807 , 0.30732924, 0.5875465 ]),
#   'fitness_score': 0.0006125465339453992},
#  {'chromosome': array([0.97905336, 0.70867109, 0.52146322, 0.14437658, 0.63522882,
#          0.61559757, 0.59422329, 0.13623545, 0.39672783]),
#   'fitness_score': 0.0009146339065632095},
#  {'chromosome': array([0.01204819, 0.85427816, 0.66200231, 0.75759244, 0.22310653,
#          0.43831842, 0.69505747, 0.42214687, 0.96193043]),
#   'fitness_score': 0.0005711389721209233},
#  {'chromosome': array([0.60090579, 0.15577601, 0.64302701, 0.33932421, 0.12429525,
#          0.15910441, 0.74540717, 0.21348278, 0.49727777]),
#   'fitness_score': 0.0027026347246383933},
#  {'chromosome': array([0.84935233, 0.26812792, 0.2764636 , 0.02261781, 0.03839523,
#          0.23435973, 0.69023211, 0.85142977, 0.73804697]),
#   'fitness_score': 0.0013250482862500548},
#  {'chromosome': array([0.87089371, 0.95689691, 0.02490632, 0.45497316, 0.97303989,
#          0.22287511, 0.68115919, 0.95282694, 0.87937709]),
#   'fitness_score': 0.0003049982843170565},
#  {'chromosome': array([0.06517179, 0.7254137 , 0.04022426, 0.51094365, 0.11912222,
#          0.51903331, 0.97905532, 0.13477728, 0.53666015]),
#   'fitness_score': 0.0013075111937748698},
#  {'chromosome': array([0.51724231, 0.53979645, 0.81809559, 0.39743134, 0.71211313,
#          0.23457949, 0.32991683, 0.00523228, 0.13720891]),
#   'fitness_score': 0.0019979131714206125},
#  {'chromosome': array([0.69474439, 0.26709266, 0.16215745, 0.92074339, 0.68539275,
#          0.67333942, 0.25158746, 0.21382204, 0.936606  ]),
#   'fitness_score': 0.0003697523603053987},
#  {'chromosome': array([0.31644848, 0.88481083, 0.46599945, 0.10970778, 0.64275054,
#          0.04477354, 0.87829854, 0.2286554 , 0.2335335 ]),
#   'fitness_score': 0.0019615257055178065},
#  {'chromosome': array([0.58721131, 0.5596065 , 0.31145157, 0.5729125 , 0.72412857,
#          0.7912855 , 0.1753202 , 0.65764635, 0.32489672]),
#   'fitness_score': 0.0005090982110498128},
#  {'chromosome': array([0.28130088, 0.32949597, 0.39570947, 0.65656363, 0.93395299,
#          0.89428623, 0.39111297, 0.63307859, 0.8189204 ]),
#   'fitness_score': 0.00025501305442096703},
#  {'chromosome': array([0.37208563, 0.42131476, 0.94983031, 0.90915452, 0.14385241,
#          0.31941872, 0.01494398, 0.76807528, 0.15600287]),
#   'fitness_score': 0.0017972854298277058},
#  {'chromosome': array([0.69906495, 0.63687171, 0.15429948, 0.53498587, 0.68253754,
#          0.42563679, 0.5111589 , 0.75621051, 0.1008179 ]),
#   'fitness_score': 0.0007906771920893415},
#  {'chromosome': array([0.92695649, 0.24644833, 0.5821229 , 0.72902711, 0.28892565,
#          0.54440313, 0.52489301, 0.33436294, 0.86701401]),
#   'fitness_score': 0.0005947161348379513},
#  {'chromosome': array([0.30014013, 0.58888908, 0.89829046, 0.05917224, 0.84422351,
#          0.72809882, 0.53079665, 0.63843666, 0.78473574]),
#   'fitness_score': 0.00036381041346756574},
#  {'chromosome': array([0.3705362 , 0.86504375, 0.90951664, 0.58430456, 0.79033156,
#          0.02548223, 0.38803523, 0.64595779, 0.55653722]),
#   'fitness_score': 0.000652734677113649},
#  {'chromosome': array([0.94131046, 0.78391259, 0.68300198, 0.80857749, 0.52490915,
#          0.089853  , 0.71234453, 0.19125772, 0.60387   ]),
#   'fitness_score': 0.0008701295482017459},
#  {'chromosome': array([0.70108809, 0.78567245, 0.50495546, 0.01259652, 0.95839835,
#          0.14656554, 0.05559453, 0.44018133, 0.4670115 ]),
#   'fitness_score': 0.0009337722344588837},
#  {'chromosome': array([0.35906239, 0.78613566, 0.96038202, 0.50640358, 0.89635636,
#          0.08412602, 0.80605922, 0.62768946, 0.5590384 ]),
#   'fitness_score': 0.0005090071800107282},
#  {'chromosome': array([0.01190927, 0.1251791 , 0.92594026, 0.93164229, 0.84996733,
#          0.9460113 , 0.7817059 , 0.26691456, 0.2972801 ]),
#   'fitness_score': 0.00036974438014207865},
#  {'chromosome': array([0.45696244, 0.88908871, 0.49969024, 0.07706816, 0.03351976,
#          0.98339009, 0.404212  , 0.898881  , 0.58702666]),
#   'fitness_score': 0.0007446816908770041},
#  {'chromosome': array([0.5821838 , 0.62245931, 0.3125742 , 0.18453542, 0.95897427,
#          0.57936563, 0.25611863, 0.05627718, 0.71540584]),
#   'fitness_score': 0.000538065312152079},
#  {'chromosome': array([0.71072354, 0.93999782, 0.57553214, 0.38184403, 0.06995004,
#          0.82505203, 0.86702968, 0.0213248 , 0.33531144]),
#   'fitness_score': 0.0015760075032795712},
#  {'chromosome': array([0.10698398, 0.34522661, 0.11699954, 0.14727083, 0.65875334,
#          0.90413991, 0.73714244, 0.4083251 , 0.18751433]),
#   'fitness_score': 0.0007010202906152015},
#  {'chromosome': array([0.52009857, 0.90258763, 0.10751599, 0.78772856, 0.79610533,
#          0.37442705, 0.45902714, 0.78972849, 0.91040767]),
#   'fitness_score': 0.00031714886403753933},
#  {'chromosome': array([0.3766663 , 0.91799756, 0.56546921, 0.6686881 , 0.60198114,
#          0.55976264, 0.76589412, 0.34583896, 0.02299888]),
#   'fitness_score': 0.0009404146460553927},
#  {'chromosome': array([0.8373153 , 0.98115386, 0.01826598, 0.07731546, 0.79292226,
#          0.52839814, 0.91170135, 0.28074564, 0.65188253]),
#   'fitness_score': 0.0005385519426585283},
#  {'chromosome': array([0.51316856, 0.08103898, 0.53191135, 0.28773814, 0.89685951,
#          0.37318805, 0.44568696, 0.39314686, 0.55515031]),
#   'fitness_score': 0.0005866454817850272},
#  {'chromosome': array([0.38291986, 0.60360119, 0.38651502, 0.8659214 , 0.92065326,
#          0.03555878, 0.39496734, 0.38634347, 0.54563322]),
#   'fitness_score': 0.0005869991673195886},
#  {'chromosome': array([0.11336246, 0.71451393, 0.47484878, 0.26067688, 0.72950021,
#          0.71056467, 0.98887862, 0.66921031, 0.28878973]),
#   'fitness_score': 0.0005049316585321498},
#  {'chromosome': array([0.24491395, 0.83381112, 0.91951121, 0.28825893, 0.85184712,
#          0.19103493, 0.12087577, 0.95907937, 0.05849195]),
#   'fitness_score': 0.0009440455928320772},
#  {'chromosome': array([0.7908309 , 0.80110968, 0.19729809, 0.92564104, 0.15206674,
#          0.3434883 , 0.96262977, 0.36787973, 0.81753758]),
#   'fitness_score': 0.0006758994182839564},
#  {'chromosome': array([0.19958929, 0.83038327, 0.99208131, 0.42426548, 0.24811749,
#          0.07415467, 0.50982108, 0.33143321, 0.40489227]),
#   'fitness_score': 0.002537287217831442},
#  {'chromosome': array([0.08022353, 0.81760861, 0.59184044, 0.27752446, 0.55259123,
#          0.51096875, 0.23758615, 0.90269128, 0.0569086 ]),
#   'fitness_score': 0.0010599702685965525},
#  {'chromosome': array([0.01642779, 0.51161589, 0.94988248, 0.20537205, 0.19972166,
#          0.46455563, 0.51972065, 0.91098442, 0.96052404]),
#   'fitness_score': 0.0005891101799136218},
#  {'chromosome': array([0.38854138, 0.16910481, 0.39478273, 0.55273983, 0.96319306,
#          0.68252275, 0.37417063, 0.63465042, 0.41444404]),
#   'fitness_score': 0.0003940826659975144},
#  {'chromosome': array([0.43638276, 0.43646135, 0.15827361, 0.39760837, 0.01468285,
#          0.05177597, 0.3696043 , 0.57966541, 0.51061122]),
#   'fitness_score': 0.003261207728376827},
#  {'chromosome': array([0.49328972, 0.70267037, 0.81326567, 0.36495863, 0.0158203 ,
#          0.14049725, 0.67704312, 0.67999925, 0.4375703 ]),
#   'fitness_score': 0.0022647409677820605},
#  {'chromosome': array([0.56860446, 0.52251598, 0.53269613, 0.6243671 , 0.66961188,
#          0.69228744, 0.67940726, 0.87968587, 0.80704656]),
#   'fitness_score': 0.0003001101414585421},
#  {'chromosome': array([0.12211606, 0.65435421, 0.60569541, 0.44024306, 0.54346064,
#          0.16438298, 0.70665473, 0.09179412, 0.68613476]),
#   'fitness_score': 0.0009917081601502982},
#  {'chromosome': array([0.57147958, 0.40898823, 0.87054413, 0.16289961, 0.73698206,
#          0.27047007, 0.60278372, 0.15105001, 0.48381625]),
#   'fitness_score': 0.0010010117052437714},
#  {'chromosome': array([0.89384178, 0.89503217, 0.18041522, 0.18377895, 0.61246088,
#          0.01614724, 0.15945638, 0.42544321, 0.42594433]),
#   'fitness_score': 0.0017556199224455277},
#  {'chromosome': array([0.89392565, 0.08204063, 0.41207711, 0.78591759, 0.68681486,
#          0.28498113, 0.72537725, 0.60954755, 0.97860159]),
#   'fitness_score': 0.0003553628980504436},
#  {'chromosome': array([0.08089222, 0.84008159, 0.51563212, 0.64655964, 0.37741448,
#          0.74731595, 0.86836171, 0.60652255, 0.3616739 ]),
#   'fitness_score': 0.0005988370049555537},
#  {'chromosome': array([0.86711236, 0.60150904, 0.0759905 , 0.69345943, 0.59047767,
#          0.58029214, 0.99321731, 0.69084951, 0.20980845]),
#   'fitness_score': 0.0005621761259530086},
#  {'chromosome': array([0.4696344 , 0.35078284, 0.93454905, 0.21586948, 0.12425581,
#          0.84377118, 0.98715762, 0.15098234, 0.58019682]),
#   'fitness_score': 0.0009622452664413722},
#  {'chromosome': array([0.79333682, 0.82290482, 0.3726414 , 0.6454475 , 0.39659228,
#          0.97411315, 0.46327646, 0.18742228, 0.24118261]),
#   'fitness_score': 0.0008046303827070168},
#  {'chromosome': array([0.35550169, 0.27955239, 0.30052457, 0.10830426, 0.26077865,
#          0.25952318, 0.28425933, 0.67475104, 0.8294315 ]),
#   'fitness_score': 0.0010635501255126555},
#  {'chromosome': array([0.53728024, 0.52450749, 0.33580972, 0.84097642, 0.10112406,
#          0.96921331, 0.21048739, 0.97888042, 0.65741702]),
#   'fitness_score': 0.00046093090653002294},
#  {'chromosome': array([0.57473613, 0.42255355, 0.62577927, 0.38226323, 0.25518687,
#          0.56126833, 0.37125842, 0.18988256, 0.63602018]),
#   'fitness_score': 0.001143302205229653},
#  {'chromosome': array([0.20071201, 0.86532596, 0.87369329, 0.78297115, 0.95435691,
#          0.36985557, 0.38819834, 0.14661821, 0.84072912]),
#   'fitness_score': 0.0003963112661725537},
#  {'chromosome': array([0.65375768, 0.13884482, 0.21406189, 0.27975925, 0.64601119,
#          0.28328115, 0.9170766 , 0.95824533, 0.86921878]),
#   'fitness_score': 0.0003986577734014369},
#  {'chromosome': array([0.34839172, 0.12883281, 0.77109322, 0.67849786, 0.04857649,
#          0.95957586, 0.92813186, 0.62133183, 0.16298934]),
#   'fitness_score': 0.0008683815334162165},
#  {'chromosome': array([0.74178403, 0.37098054, 0.38427882, 0.07302605, 0.14240916,
#          0.45658689, 0.02398979, 0.05379494, 0.59865028]),
#   'fitness_score': 0.003245990028420516},
#  {'chromosome': array([0.86833842, 0.98683379, 0.98123628, 0.34346292, 0.90728316,
#          0.46879093, 0.47513806, 0.88555232, 0.44850043]),
#   'fitness_score': 0.0004206787349655605},
#  {'chromosome': array([0.23756197, 0.35183361, 0.94853162, 0.0259982 , 0.94202945,
#          0.48245435, 0.12916426, 0.13466631, 0.19787481]),
#   'fitness_score': 0.0011484312225400058},
#  {'chromosome': array([0.68385813, 0.63462385, 0.54900567, 0.59100464, 0.55422432,
#          0.10301412, 0.1963081 , 0.60239131, 0.60358898]),
#   'fitness_score': 0.0008609412573199946},
#  {'chromosome': array([0.68217678, 0.1622723 , 0.87359026, 0.69927624, 0.57376211,
#          0.22531698, 0.49982183, 0.04998643, 0.69612416]),
#   'fitness_score': 0.0008274471767303314},
#  {'chromosome': array([0.77604637, 0.43606127, 0.25031275, 0.07103004, 0.47652477,
#          0.17580046, 0.31926328, 0.90125136, 0.27080384]),
#   'fitness_score': 0.0014874399425863383},
#  {'chromosome': array([0.90061541, 0.58287535, 0.23227155, 0.50157712, 0.28936271,
#          0.3333192 , 0.36993198, 0.99809714, 0.14985134]),
#   'fitness_score': 0.0012911501614488678},
#  {'chromosome': array([0.84813311, 0.25833966, 0.21681891, 0.5647895 , 0.27024823,
#          0.74419717, 0.06577315, 0.06553303, 0.07821263]),
#   'fitness_score': 0.0024617952726350566},
#  {'chromosome': array([0.76551153, 0.17604733, 0.36365148, 0.26944778, 0.39088542,
#          0.37432191, 0.69921085, 0.7080036 , 0.23692683]),
#   'fitness_score': 0.0012150779682903751},
#  {'chromosome': array([0.47460132, 0.84880149, 0.11666095, 0.8726115 , 0.27968207,
#          0.04305487, 0.00618557, 0.6029422 , 0.8727467 ]),
#   'fitness_score': 0.0008969795639959727},
#  {'chromosome': array([0.49411693, 0.29678661, 0.63012865, 0.63853736, 0.15810701,
#          0.54240177, 0.5477942 , 0.53673197, 0.64972368]),
#   'fitness_score': 0.0008081923351119931},
#  {'chromosome': array([0.67638239, 0.52519786, 0.73789703, 0.80832852, 0.12661216,
#          0.49612636, 0.47321106, 0.99958301, 0.31869828]),
#   'fitness_score': 0.0008527160629839555},
#  {'chromosome': array([0.33359599, 0.11530738, 0.03213141, 0.55257467, 0.42906979,
#          0.69516342, 0.71703434, 0.63027693, 0.77263781]),
#   'fitness_score': 0.00044736598049115026},
#  {'chromosome': array([0.83703705, 0.75887382, 0.48782794, 0.29162329, 0.52015411,
#          0.56016253, 0.3647993 , 0.86519975, 0.69299579]),
#   'fitness_score': 0.0005087724118537349},
#  {'chromosome': array([0.41390348, 0.02146923, 0.30172992, 0.77386463, 0.94096456,
#          0.20981961, 0.30446295, 0.25059476, 0.55975798]),
#   'fitness_score': 0.0005789157966147822},
#  {'chromosome': array([0.15738181, 0.9360795 , 0.79305948, 0.50090587, 0.2348355 ,
#          0.74018134, 0.72257568, 0.24528008, 0.61097312]),
#   'fitness_score': 0.0007770654712604541},
#  {'chromosome': array([0.4225769 , 0.60331362, 0.77825623, 0.45826445, 0.4680656 ,
#          0.07508146, 0.68665815, 0.57933802, 0.42934838]),
#   'fitness_score': 0.0011337863095801717},
#  {'chromosome': array([0.54295871, 0.95482364, 0.28497365, 0.05932364, 0.34425053,
#          0.96163833, 0.76089417, 0.60541709, 0.90015888]),
#   'fitness_score': 0.00043244053538727724},
#  {'chromosome': array([0.55721308, 0.67092645, 0.72451615, 0.80435282, 0.121462  ,
#          0.49329541, 0.1668721 , 0.94072562, 0.45758913]),
#   'fitness_score': 0.0008597933284164648},
#  {'chromosome': array([0.32060804, 0.29120638, 0.52428175, 0.54796786, 0.11970756,
#          0.33512923, 0.91479878, 0.42380516, 0.52641834]),
#   'fitness_score': 0.001259683355828761},
#  {'chromosome': array([0.04381193, 0.93203341, 0.66754687, 0.79158549, 0.5386141 ,
#          0.15021575, 0.13058212, 0.06385403, 0.27776007]),
#   'fitness_score': 0.001904932539021926},
#  {'chromosome': array([0.86040348, 0.17611583, 0.40915484, 0.85937485, 0.42308403,
#          0.08330303, 0.57858909, 0.90472111, 0.9325629 ]),
#   'fitness_score': 0.0004716833715724945},
#  {'chromosome': array([0.17896378, 0.96612593, 0.65044115, 0.9499751 , 0.03774056,
#          0.79114974, 0.07006149, 0.92620781, 0.79664695]),
#   'fitness_score': 0.0005026503253195729},
#  {'chromosome': array([0.54090622, 0.33174034, 0.84136746, 0.25199643, 0.00477019,
#          0.87156394, 0.04905688, 0.62793827, 0.84529636]),
#   'fitness_score': 0.00079531325102628},
#  {'chromosome': array([0.02079985, 0.56148262, 0.72209391, 0.20958733, 0.59178446,
#          0.97251842, 0.9105741 , 0.39617825, 0.31067614]),
#   'fitness_score': 0.0005682727330068771},
#  {'chromosome': array([0.78084671, 0.98396176, 0.90624693, 0.51078333, 0.89612412,
#          0.02628852, 0.66285826, 0.82918833, 0.39975068]),
#   'fitness_score': 0.000566720017253686},
#  {'chromosome': array([0.05892797, 0.12979201, 0.79117087, 0.96873162, 0.66574162,
#          0.96711245, 0.05008289, 0.17661764, 0.93046533]),
#   'fitness_score': 0.00032699837974987695},
#  {'chromosome': array([0.73379289, 0.0150351 , 0.6770464 , 0.10801861, 0.25844623,
#          0.82173754, 0.43068424, 0.14583946, 0.29788895]),
#   'fitness_score': 0.0016697168849799059}]

# %%
for generation in range(num_of_generations):
    population_with_scores = sorted(population_with_scores, key = lambda x:x['fitness_score'], reverse=True)
    new_generation = [] 
    population = [el['chromosome'] for el in population_with_scores]

    s = int((10*len(population_with_scores))/100)
    new_generation.extend(population[:s])

    s = int((90*len(population_with_scores))/100)
    for _ in range(s): 
        parent1 = np.random.choice(population[:50]) 
        parent2 = np.random.choice(population[:50])
        if np.random.rand() < 0.9:
            crossover_point = np.random.randint(1, len(parameters)-1)
            offspring1 = np.concatenate([parent1[:crossover_point], parent2[crossover_point:]])
            offspring2 = np.concatenate([parent2[:crossover_point], parent1[crossover_point:]])
        else:
            offspring1, offspring2 = parent1, parent2
        new_generation.extend([offspring1, offspring2])

    for offspring in new_generation:
        if np.random.rand() < 0.01:
            mutation_point = np.random.randint(len(parameters))
            offspring[mutation_point] = np.random.rand()

    population = np.array(new_generation)
    fitness_scores = np.array([fitness_score(chrom, training_data, training_data_ranking) for chrom in population])
    population_with_scores = [{'chromosome': population[i], 'fitness_score': fitness_scores[i]} for i in range(len(fitness_scores))]
    
best_chromosome = sorted(population_with_scores, key = lambda x:x['fitness_score'], reverse=True)[0]
best_chromosome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[223], line 11
#       9 s = int((90*len(population_with_scores))/100)
#      10 for _ in range(s):
# ---> 11     parent1 = random.choice(population[:50])
#      12     parent2 = random.choice(population[:50])
#      13     if np.random.rand() < 0.9:
#
# NameError: name 'random' is not defined
