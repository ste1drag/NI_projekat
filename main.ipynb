# %%
import pandas as pd
import numpy as np
from add_rankings import add_rankings
from sklearn import linear_model
from scipy.optimize import minimize
from joblib import Parallel, delayed

# %%
def calculate_team_stats(path):
    df = pd.read_excel(path)

    required_columns = ['Club', '2FG', '3FG', 'FT', 'Fouls(Rv)', 'PIR']
    if not all(column in df.columns for column in required_columns):
        raise ValueError(f"The file must contain required columns")
    
    df[['2pt_made','2pt_attempted']] = df['2FG'].str.split('/', expand = True).astype(int)
    df[['3pt_made','3pt_attempted']] = df['3FG'].str.split('/', expand = True).astype(int)
    df[['ft_made','ft_attempted']] = df['FT'].str.split('/', expand = True).astype(int)

    df['Fouls(Rv)'] = df['Fouls(Rv)'].astype(int)
    df['PIR'] = df['PIR'].astype(int)

    team_stats = df.groupby('Club').agg({
        '2pt_made': 'sum',
        '3pt_made': 'sum',
        'ft_made': 'sum',
        'Fouls(Rv)':'sum',
        'PIR': 'sum'
    }).reset_index()

    return team_stats

# %%
path = 'data/Euroleague_20_21.xlsx'
team_stats = calculate_team_stats(path)

# %%
team_stats
# Out:
#                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 1                  Alba Berlin       647       342      354        664  2863
# 2                 Anadolu Efes       795       418      609        836  3908
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 4                  CSKA Moscow       759       388      599        847  3516
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
# 6                 FC Barcelona       855       324      598        866  3566
# 7             FC Bayern Munich       831       281      561        801  3201
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 9         Khimki Moscow Region       620       315      449        630  2626
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 14                 Real Madrid       720       400      458        734  3429
# 15             Valencia Basket       668       318      493        697  3075
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 17         Zenit St Petersburg       705       358      537        803  3266

# %%
team_stats['score'] = 47.19 + 0.15 * team_stats['Fouls(Rv)'] + 0.78 * team_stats['2pt_made'] + 1.39 * team_stats['3pt_made'] + 0.54 * team_stats['ft_made']

# %%
team_stats.info
# Out:
# <bound method DataFrame.info of                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR  \
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 1                  Alba Berlin       647       342      354        664  2863
# 2                 Anadolu Efes       795       418      609        836  3908
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 4                  CSKA Moscow       759       388      599        847  3516
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
# 6                 FC Barcelona       855       324      598        866  3566
# 7             FC Bayern Munich       831       281      561        801  3201
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 9         Khimki Moscow Region       620       315      449        630  2626
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 14                 Real Madrid       720       400      458        734  3429
# 15             Valencia Basket       668       318      493        697  3075
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 17         Zenit St Petersburg       705       358      537        803  3266
#
#       score
# 0   1647.69
# 1   1317.99
# 2   1702.57
# 3   1356.71
# 4   1629.04
# 5   1266.73
# 6   1617.27
# 7   1509.05
# 8   1401.61
# 9   1305.60
# 10  1296.34
# 11  1317.15
# 12  1327.48
# 13  1341.69
# 14  1522.21
# 15  1381.02
# 16  1295.63
# 17  1505.14  >

# %%
team_stats = team_stats.sort_values(by=['score']).iloc[::-1]

# %%
team_stats
# Out:
#                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR  \
# 2                 Anadolu Efes       795       418      609        836  3908
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 4                  CSKA Moscow       759       388      599        847  3516
# 6                 FC Barcelona       855       324      598        866  3566
# 14                 Real Madrid       720       400      458        734  3429
# 7             FC Bayern Munich       831       281      561        801  3201
# 17         Zenit St Petersburg       705       358      537        803  3266
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 15             Valencia Basket       668       318      493        697  3075
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 1                  Alba Berlin       647       342      354        664  2863
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 9         Khimki Moscow Region       620       315      449        630  2626
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
#
#       score
# 2   1702.57
# 0   1647.69
# 4   1629.04
# 6   1617.27
# 14  1522.21
# 7   1509.05
# 17  1505.14
# 8   1401.61
# 15  1381.02
# 3   1356.71
# 13  1341.69
# 12  1327.48
# 1   1317.99
# 11  1317.15
# 9   1305.60
# 10  1296.34
# 16  1295.63
# 5   1266.73

# %%
team_stats_pir = team_stats.sort_values(by=['PIR']).iloc[::-1]

# %%
team_stats_pir
# Out:
#                           Club  2pt_made  3pt_made  ft_made  Fouls(Rv)   PIR  \
# 2                 Anadolu Efes       795       418      609        836  3908
# 6                 FC Barcelona       855       324      598        866  3566
# 4                  CSKA Moscow       759       388      599        847  3516
# 0     AX Armani Exchange Milan       797       387      589        819  3514
# 14                 Real Madrid       720       400      458        734  3429
# 17         Zenit St Petersburg       705       358      537        803  3266
# 7             FC Bayern Munich       831       281      561        801  3201
# 3     Baskonia Vitoria-Gasteiz       685       314      439        678  3183
# 8     Fenerbahce Beko Istanbul       781       301      415        685  3106
# 15             Valencia Basket       668       318      493        697  3075
# 16             Zalgiris Kaunas       683       287      403        661  2873
# 1                  Alba Berlin       647       342      354        664  2863
# 13   Panathinaikos Opap Athens       672       303      458        679  2862
# 12          Olympiacos Piraeus       653       298      472        679  2816
# 11   Maccabi Playtika Tel Aviv       665       300      434        666  2771
# 10     LDLC ASVEL Villeurbanne       648       286      453        677  2687
# 9         Khimki Moscow Region       620       315      449        630  2626
# 5   Crvena Zvezda Mts Belgrade       587       292      470        680  2469
#
#       score
# 2   1702.57
# 6   1617.27
# 4   1629.04
# 0   1647.69
# 14  1522.21
# 17  1505.14
# 7   1509.05
# 3   1356.71
# 8   1401.61
# 15  1381.02
# 16  1295.63
# 1   1317.99
# 13  1341.69
# 12  1327.48
# 11  1317.15
# 10  1296.34
# 9   1305.60
# 5   1266.73

# %%
data = add_rankings('data/euroleague_teams.csv')

# %%
training_data = data[data['ranking'].notna()]

# %%
training_data
# Out:
#     season_team_id season_code team_id  games_played  minutes  points  \
# 216      E2016_BAM       E2016     BAM          30.0   1214.3    2397
# 217      E2016_BAR       E2016     BAR          30.0   1205.0    2141
# 218      E2016_BAS       E2016     BAS          33.0   1319.8    2705
# 219      E2016_CSK       E2016     CSK          35.0   1409.9    3063
# 220      E2016_DAR       E2016     DAR          34.0   1365.0    2691
# ..             ...         ...     ...           ...      ...     ...
# 331      E2022_RED       E2022     RED          34.0   1375.0    2626
# 332      E2022_TEL       E2022     TEL          39.0   1565.0    3262
# 333      E2022_ULK       E2022     ULK          39.0   1575.0    3229
# 334      E2022_VIR       E2022     VIR          34.0   1365.0    2653
# 335      E2022_ZAL       E2022     ZAL          37.0   1480.0    2807
#
#      two_points_made  two_points_attempted  three_points_made  \
# 216              602                  1098                280
# 217              496                  1022                271
# 218              719                  1349                270
# 219              745                  1351                305
# 220              646                  1322                304
# ..               ...                   ...                ...
# 331              657                  1205                281
# 332              841                  1521                348
# 333              814                  1469                372
# 334              628                  1151                301
# 335              708                  1371                288
#
#      three_points_attempted  ...  total_rebounds_per_game  assists_per_game  \
# 216                     697  ...                    31.57             18.23
# 217                     716  ...                    33.83             17.23
# 218                     763  ...                    36.55             18.39
# 219                     756  ...                    33.46             19.86
# 220                     826  ...                    34.88             13.97
# ..                      ...  ...                      ...               ...
# 331                     832  ...                    32.76             16.91
# 332                    1000  ...                    35.69             16.38
# 333                     997  ...                    33.49             17.97
# 334                     805  ...                    30.79             19.44
# 335                     797  ...                    33.32             13.70
#
#      steals_per_game  turnovers_per_game  blocks_favour_per_game  \
# 216             5.47               12.50                    2.73
# 217             7.07               14.77                    2.03
# 218             6.70               13.70                    3.03
# 219             7.11               14.31                    3.23
# 220             6.15               11.09                    2.47
# ..               ...                 ...                     ...
# 331             6.65               12.53                    1.65
# 332             6.62               11.44                    2.90
# 333             6.49               11.77                    1.59
# 334             7.12               14.53                    2.09
# 335             6.00               12.95                    2.46
#
#      blocks_against_per_game  fouls_committed_per_game  \
# 216                     2.57                     21.93
# 217                     2.13                     18.43
# 218                     2.82                     21.58
# 219                     3.09                     22.60
# 220                     3.82                     20.32
# ..                       ...                       ...
# 331                     2.65                     21.47
# 332                     2.13                     22.44
# 333                     2.46                     20.79
# 334                     2.47                     20.88
# 335                     2.81                     20.65
#
#      fouls_received_per_game  valuation_per_game  ranking
# 216                    18.93               86.13     13.0
# 217                    19.83               79.67     11.0
# 218                    20.64               90.85      8.0
# 219                    22.80               99.69      1.0
# 220                    20.76               81.71      9.0
# ..                       ...                 ...      ...
# 331                    20.12               82.35     11.0
# 332                    19.26               90.74      5.0
# 333                    20.41               90.13      7.0
# 334                    20.06               85.65     14.0
# 335                    20.27               80.05      9.0
#
# [119 rows x 46 columns]

# %%
test_data = data[data['season_team_id'].str.startswith('E2023')]

# %%
test_data
# Out:
#     season_team_id season_code team_id  games_played  minutes  points  \
# 336      E2023_ASV       E2023     ASV          34.0   1370.0    2674
# 337      E2023_BAR       E2023     BAR          39.0   1565.0    3163
# 338      E2023_BAS       E2023     BAS          39.0   1565.0    3300
# 339      E2023_BER       E2023     BER          34.0   1360.0    2591
# 340      E2023_IST       E2023     IST          35.0   1425.0    2992
# 341      E2023_MAD       E2023     MAD          39.0   1590.0    3459
# 342      E2023_MCO       E2023     MCO          39.0   1575.0    3189
# 343      E2023_MIL       E2023     MIL          34.0   1370.0    2659
# 344      E2023_MUN       E2023     MUN          34.0   1385.0    2674
# 345      E2023_OLY       E2023     OLY          41.0   1660.0    3229
# 346      E2023_PAM       E2023     PAM          34.0   1365.0    2582
# 347      E2023_PAN       E2023     PAN          41.0   1653.0    3380
# 348      E2023_PAR       E2023     PAR          34.0   1375.0    2822
# 349      E2023_RED       E2023     RED          34.0   1360.0    2764
# 350      E2023_TEL       E2023     TEL          40.0   1603.0    3508
# 351      E2023_ULK       E2023     ULK          41.0   1670.0    3449
# 352      E2023_VIR       E2023     VIR          36.0   1440.0    2872
# 353      E2023_ZAL       E2023     ZAL          34.0   1365.0    2702
#
#      two_points_made  two_points_attempted  three_points_made  \
# 336              744                  1388                244
# 337              856                  1568                328
# 338              752                  1351                424
# 339              641                  1260                302
# 340              747                  1346                348
# 341              820                  1414                407
# 342              849                  1601                305
# 343              615                  1116                341
# 344              649                  1215                336
# 345              772                  1396                387
# 346              686                  1309                247
# 347              812                  1475                377
# 348              750                  1282                273
# 349              680                  1239                314
# 350              919                  1710                356
# 351              759                  1365                470
# 352              702                  1295                338
# 353              646                  1217                331
#
#      three_points_attempted  ...  total_rebounds_per_game  assists_per_game  \
# 336                     723  ...                    33.97             17.82
# 337                     912  ...                    35.85             19.31
# 338                    1143  ...                    34.97             18.97
# 339                     860  ...                    32.44             16.44
# 340                     940  ...                    32.54             17.63
# 341                    1076  ...                    36.44             20.59
# 342                     872  ...                    33.87             16.05
# 343                     930  ...                    32.12             16.29
# 344                     938  ...                    35.41             16.09
# 345                    1030  ...                    33.20             19.02
# 346                     754  ...                    34.32             16.18
# 347                     966  ...                    33.76             16.59
# 348                     755  ...                    30.91             15.09
# 349                     920  ...                    34.74             18.47
# 350                     973  ...                    35.60             19.58
# 351                    1199  ...                    33.29             18.05
# 352                     936  ...                    32.75             18.61
# 353                     851  ...                    31.88             15.65
#
#      steals_per_game  turnovers_per_game  blocks_favour_per_game  \
# 336             6.03               12.97                    1.62
# 337             6.41               12.79                    2.28
# 338             5.51               12.46                    2.21
# 339             7.00               15.09                    2.15
# 340             7.03               10.34                    3.14
# 341             6.51               12.03                    3.62
# 342             6.87                9.97                    1.82
# 343             7.00               12.44                    2.12
# 344             6.06               13.03                    2.62
# 345             7.17               12.15                    2.61
# 346             6.47               13.62                    1.82
# 347             6.76               12.46                    2.68
# 348             6.56               12.44                    2.32
# 349             6.59               12.12                    2.47
# 350             7.10               11.68                    3.05
# 351             5.85               12.07                    2.22
# 352             6.64               12.31                    2.69
# 353             6.50               12.59                    1.74
#
#      blocks_against_per_game  fouls_committed_per_game  \
# 336                     3.29                     18.41
# 337                     1.92                     19.85
# 338                     3.38                     18.18
# 339                     3.50                     18.32
# 340                     2.14                     18.31
# 341                     1.56                     18.90
# 342                     2.21                     19.62
# 343                     1.74                     19.56
# 344                     2.47                     20.65
# 345                     2.41                     18.93
# 346                     3.12                     21.15
# 347                     2.41                     17.68
# 348                     1.59                     21.06
# 349                     2.74                     21.56
# 350                     2.33                     20.38
# 351                     1.73                     21.39
# 352                     2.19                     21.58
# 353                     2.88                     21.18
#
#      fouls_received_per_game  valuation_per_game  ranking
# 336                    19.35               85.82      NaN
# 337                    18.95               91.59      NaN
# 338                    18.79               93.05      NaN
# 339                    18.18               77.76      NaN
# 340                    18.51               96.51      NaN
# 341                    20.08              107.56      NaN
# 342                    21.56               91.36      NaN
# 343                    18.97               85.47      NaN
# 344                    18.79               84.38      NaN
# 345                    19.61               91.24      NaN
# 346                    19.12               78.71      NaN
# 347                    21.63               95.32      NaN
# 348                    20.41               90.12      NaN
# 349                    19.88               88.71      NaN
# 350                    19.40               98.58      NaN
# 351                    19.73               92.20      NaN
# 352                    19.56               86.69      NaN
# 353                    18.32               81.94      NaN
#
# [18 rows x 46 columns]

# %%
model = linear_model.LinearRegression()

# %%
training_data_ranking = training_data['ranking']

# %%
training_data_ranking
# Out:
# 216    13.0
# 217    11.0
# 218     8.0
# 219     1.0
# 220     9.0
#        ...
# 331    11.0
# 332     5.0
# 333     7.0
# 334    14.0
# 335     9.0
# Name: ranking, Length: 119, dtype: float64

# %%
training_data['two_points_percentage'] = training_data['two_points_made_per_game'] / training_data['two_points_attempted_per_game']
training_data['three_points_percentage'] = training_data['three_points_made_per_game'] / training_data['three_points_attempted_per_game']
training_data['free_throws_percentage'] = training_data['free_throws_made_per_game'] / training_data['free_throws_attempted_per_game']
parameters = ['two_points_percentage','three_points_percentage','free_throws_percentage','assists_per_game','turnovers_per_game','fouls_received_per_game']
# Out:
# C:\Users\steva\AppData\Local\Temp\ipykernel_13596\378270635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['two_points_percentage'] = training_data['two_points_made_per_game'] / training_data['two_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_13596\378270635.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['three_points_percentage'] = training_data['three_points_made_per_game'] / training_data['three_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_13596\378270635.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['free_throws_percentage'] = training_data['free_throws_made_per_game'] / training_data['free_throws_attempted_per_game']

# %%
training_data = training_data[parameters]

# %%
training_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 216               0.548361                 0.401636                0.783100
# 217               0.485178                 0.378299                0.736842
# 218               0.533023                 0.353806                0.763085
# 219               0.551554                 0.403241                0.821319
# 220               0.488683                 0.368053                0.733231
# ..                     ...                      ...                     ...
# 331               0.545147                 0.337556                0.775155
# 332               0.552821                 0.347894                0.792845
# 333               0.554022                 0.373239                0.722836
# 334               0.545643                 0.373733                0.793122
# 335               0.516599                 0.361188                0.803158
#
#      assists_per_game  turnovers_per_game  fouls_received_per_game
# 216             18.23               12.50                    18.93
# 217             17.23               14.77                    19.83
# 218             18.39               13.70                    20.64
# 219             19.86               14.31                    22.80
# 220             13.97               11.09                    20.76
# ..                ...                 ...                      ...
# 331             16.91               12.53                    20.12
# 332             16.38               11.44                    19.26
# 333             17.97               11.77                    20.41
# 334             19.44               14.53                    20.06
# 335             13.70               12.95                    20.27
#
# [119 rows x 6 columns]

# %%
model.fit(training_data,training_data_ranking)
# Out:
# LinearRegression()

# %%
test_data['two_points_percentage'] = test_data['two_points_made_per_game'] / test_data['two_points_attempted_per_game']
test_data['three_points_percentage'] = test_data['three_points_made_per_game'] / test_data['three_points_attempted_per_game']
test_data['free_throws_percentage'] = test_data['free_throws_made_per_game'] / test_data['free_throws_attempted_per_game']
# Out:
# C:\Users\steva\AppData\Local\Temp\ipykernel_13596\1492303578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['two_points_percentage'] = test_data['two_points_made_per_game'] / test_data['two_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_13596\1492303578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['three_points_percentage'] = test_data['three_points_made_per_game'] / test_data['three_points_attempted_per_game']
# C:\Users\steva\AppData\Local\Temp\ipykernel_13596\1492303578.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['free_throws_percentage'] = test_data['free_throws_made_per_game'] / test_data['free_throws_attempted_per_game']

# %%
test_data = test_data[parameters]

# %%
test_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 336               0.536012                 0.337723                0.773465
# 337               0.545884                 0.359709                0.725894
# 338               0.556582                 0.370863                0.761905
# 339               0.508635                 0.351127                0.791583
# 340               0.554862                 0.370067                0.812148
# 341               0.579978                 0.378398                0.814559
# 342               0.530329                 0.349732                0.748227
# 343               0.551188                 0.366728                0.776333
# 344               0.534135                 0.358101                0.797935
# 345               0.553010                 0.375796                0.729869
# 346               0.524156                 0.327322                0.773850
# 347               0.550306                 0.390492                0.736944
# 348               0.584991                 0.361549                0.818937
# 349               0.548847                 0.341463                0.769972
# 350               0.537544                 0.365954                0.778986
# 351               0.556023                 0.391929                0.793383
# 352               0.542118                 0.361154                0.751490
# 353               0.530875                 0.389133                0.809241
#
#      assists_per_game  turnovers_per_game  fouls_received_per_game
# 336             17.82               12.97                    19.35
# 337             19.31               12.79                    18.95
# 338             18.97               12.46                    18.79
# 339             16.44               15.09                    18.18
# 340             17.63               10.34                    18.51
# 341             20.59               12.03                    20.08
# 342             16.05                9.97                    21.56
# 343             16.29               12.44                    18.97
# 344             16.09               13.03                    18.79
# 345             19.02               12.15                    19.61
# 346             16.18               13.62                    19.12
# 347             16.59               12.46                    21.63
# 348             15.09               12.44                    20.41
# 349             18.47               12.12                    19.88
# 350             19.58               11.68                    19.40
# 351             18.05               12.07                    19.73
# 352             18.61               12.31                    19.56
# 353             15.65               12.59                    18.32

# %%
rankings_2023_predicted = model.predict(test_data)

# %%
test_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 336               0.536012                 0.337723                0.773465
# 337               0.545884                 0.359709                0.725894
# 338               0.556582                 0.370863                0.761905
# 339               0.508635                 0.351127                0.791583
# 340               0.554862                 0.370067                0.812148
# 341               0.579978                 0.378398                0.814559
# 342               0.530329                 0.349732                0.748227
# 343               0.551188                 0.366728                0.776333
# 344               0.534135                 0.358101                0.797935
# 345               0.553010                 0.375796                0.729869
# 346               0.524156                 0.327322                0.773850
# 347               0.550306                 0.390492                0.736944
# 348               0.584991                 0.361549                0.818937
# 349               0.548847                 0.341463                0.769972
# 350               0.537544                 0.365954                0.778986
# 351               0.556023                 0.391929                0.793383
# 352               0.542118                 0.361154                0.751490
# 353               0.530875                 0.389133                0.809241
#
#      assists_per_game  turnovers_per_game  fouls_received_per_game
# 336             17.82               12.97                    19.35
# 337             19.31               12.79                    18.95
# 338             18.97               12.46                    18.79
# 339             16.44               15.09                    18.18
# 340             17.63               10.34                    18.51
# 341             20.59               12.03                    20.08
# 342             16.05                9.97                    21.56
# 343             16.29               12.44                    18.97
# 344             16.09               13.03                    18.79
# 345             19.02               12.15                    19.61
# 346             16.18               13.62                    19.12
# 347             16.59               12.46                    21.63
# 348             15.09               12.44                    20.41
# 349             18.47               12.12                    19.88
# 350             19.58               11.68                    19.40
# 351             18.05               12.07                    19.73
# 352             18.61               12.31                    19.56
# 353             15.65               12.59                    18.32

# %%
model.coef_
# Out:
# array([-70.83107446, -70.24644   ,  26.1422947 ,  -0.14393614,
#          1.19242699,  -1.06324903])

# %%
sorted_ranking = sorted(rankings_2023_predicted)

order_ranking = {value: index + 1 for index, value in enumerate(sorted_ranking)}

result = [order_ranking[value] for value in rankings_2023_predicted]

# %%
result
# Out:
# [15, 11, 8, 18, 7, 2, 3, 12, 16, 4, 17, 1, 6, 13, 9, 5, 10, 14]

# %%
test_data
# Out:
#      two_points_percentage  three_points_percentage  free_throws_percentage  \
# 336               0.536012                 0.337723                0.773465
# 337               0.545884                 0.359709                0.725894
# 338               0.556582                 0.370863                0.761905
# 339               0.508635                 0.351127                0.791583
# 340               0.554862                 0.370067                0.812148
# 341               0.579978                 0.378398                0.814559
# 342               0.530329                 0.349732                0.748227
# 343               0.551188                 0.366728                0.776333
# 344               0.534135                 0.358101                0.797935
# 345               0.553010                 0.375796                0.729869
# 346               0.524156                 0.327322                0.773850
# 347               0.550306                 0.390492                0.736944
# 348               0.584991                 0.361549                0.818937
# 349               0.548847                 0.341463                0.769972
# 350               0.537544                 0.365954                0.778986
# 351               0.556023                 0.391929                0.793383
# 352               0.542118                 0.361154                0.751490
# 353               0.530875                 0.389133                0.809241
#
#      assists_per_game  turnovers_per_game  fouls_received_per_game
# 336             17.82               12.97                    19.35
# 337             19.31               12.79                    18.95
# 338             18.97               12.46                    18.79
# 339             16.44               15.09                    18.18
# 340             17.63               10.34                    18.51
# 341             20.59               12.03                    20.08
# 342             16.05                9.97                    21.56
# 343             16.29               12.44                    18.97
# 344             16.09               13.03                    18.79
# 345             19.02               12.15                    19.61
# 346             16.18               13.62                    19.12
# 347             16.59               12.46                    21.63
# 348             15.09               12.44                    20.41
# 349             18.47               12.12                    19.88
# 350             19.58               11.68                    19.40
# 351             18.05               12.07                    19.73
# 352             18.61               12.31                    19.56
# 353             15.65               12.59                    18.32

# %%
# implementing genetic algorithm

# %%
num_of_generations = 20
population = np.random.rand(50, len(parameters))

# %%
len(population)
# Out:
# 50

# %%
crossover = np.random.rand()

# %%
def fitness_for_single_chromosome(chromosome):
    predictions = chromosome.dot(training_data.values.T)
    mse = np.mean((predictions - training_data_ranking.values) ** 2)
    regularization = 0.01 * np.sum(chromosome ** 2)
    return 1 / (1 + mse + regularization)

def fitness_scores(population):
    fitness_score_arr=Parallel(n_jobs=-1)(delayed(fitness_for_single_chromosome)(chrom) for chrom in population)
    return fitness_score_arr

# %%
def apply_gradient_descent(solution):
    result = minimize(fitness_for_single_chromosome, solution, method='BFGS')
    return result.x

# %%
fitness_score_arr = fitness_scores(population)
len(fitness_score_arr)
# Out:
# 50

# %%
population_with_scores = [{'chromosome': population[i], 'fitness_score': fitness_score_arr[i]} for i in range(len(fitness_score_arr))]

# %%
population_with_scores
initial_mutation_rate = 0.1
initial_mutation_strength = 0.1

# %%
for generation in range(num_of_generations):
    sorted_indices = np.argsort(fitness_score_arr)[::-1]
    population = population[sorted_indices]
    fitness_score_arr = fitness_score_arr[sorted_indices]
    
    # Elitism
    top_indices = sorted_indices[:int(0.1 * len(fitness_score_arr))]
    new_generation = population[top_indices]
    
    # Crossover with multi-point crossover
    num_offspring = int(0.9 * len(population))
    parent_indices = np.random.choice(range(11), size=(num_offspring, 2))
    crossover_points = np.sort(np.random.choice(range(1, len(parameters) - 1), size=2, replace=False))
    offspring1 = np.array([np.concatenate([population[parent1][:crossover_points[0]], 
                                           population[parent2][crossover_points[0]:crossover_points[1]], 
                                           population[parent1][crossover_points[1]:]])
                           for (parent1, parent2) in parent_indices])

    offspring2 = np.array([np.concatenate([population[parent2][:crossover_points[0]], 
                                           population[parent1][crossover_points[0]:crossover_points[1]], 
                                           population[parent2][crossover_points[1]:]])
                           for (parent1, parent2) in parent_indices])
    new_generation = np.concatenate([new_generation, offspring1, offspring2])

    # Mutation with Gaussian perturbation
    mutation_rate = initial_mutation_rate * (1 - (generation / num_of_generations))
    mutation_strength = initial_mutation_strength * (1 - (generation / num_of_generations))
    mutation_mask = np.random.rand(len(new_generation), len(parameters)) < mutation_rate
    new_generation += mutation_mask * np.random.normal(0, mutation_strength, new_generation.shape)

    # Periodic application of gradient descent
    if generation % 3 == 0:
        for i in range(min(3, len(new_generation))):  # Ensure not to index out of bounds
            new_generation[i] = apply_gradient_descent(new_generation[i])

    population = np.array(new_generation)
    fitness_score_arr = fitness_scores(population)
        
    
best_chromosome = population[0]
best_chromosome
best_score = fitness_score_arr[0]
best_score
# Out:
# 0.04718573800909435

# %%
predicted_rankings = np.dot(test_data[parameters], population[0])

# %%
sorted_ranking_pr = sorted(predicted_rankings)

order_ranking = {value: index + 1 for index, value in enumerate(sorted_ranking_pr)}

result_pr = [order_ranking[value] for value in predicted_rankings]

# %%
result_pr
# Out:
# [13, 10, 9, 18, 2, 4, 1, 12, 16, 5, 17, 11, 14, 6, 3, 7, 8, 15]

# %%
best_chromosome
# Out:
# array([ 0.15594283,  0.55709123,  0.83109734, -0.46157272,  1.49501047,
#        -0.11750917])

# %%
population_with_scores = [{'chromosome': population[i], 'fitness_score': fitness_score_arr[i]} for i in range(len(fitness_score_arr))]

# %%
best_chromosome = sorted(population_with_scores, key = lambda x:x['fitness_score'], reverse=True)[0]
best_chromosome
# Out:
# {'chromosome': array([ 0.15594283,  0.55709123,  0.83109734, -0.48050821,  1.56466074,
#         -0.1600181 ]),
#  'fitness_score': 0.04785909028806224}

# %%
predicted_rankings = np.dot(test_data[parameters], best_chromosome['chromosome'])
sorted_ranking_pr = sorted(predicted_rankings)

order_ranking = {value: index + 1 for index, value in enumerate(sorted_ranking_pr)}

result_pr = [order_ranking[value] for value in predicted_rankings]

# %%
result_pr
# Out:
# [13, 10, 9, 18, 2, 3, 1, 12, 16, 5, 17, 11, 14, 6, 4, 7, 8, 15]
